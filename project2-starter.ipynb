# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
len (df_raw)
# Out:
# 400

# %% [markdown]
# Answer: there are 400 observations

# %% [markdown]
# #### Question 2. Create a summary table

# %%
#function

# %%
df_raw.describe()
# Out:
# C:\Users\updadmin\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: because the range in GRE is larger by nature (scores 600-800) and in GPA only 2-4

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_no_missing = df_raw.dropna()
df_no_missing

df_raw.isnull().sum()
# Out:
# admit       0
# gre         2
# gpa         2
# prestige    1
# dtype: int64

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %%
df_no_missing.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397 entries, 0 to 399
# Data columns (total 4 columns):
# admit       397 non-null int64
# gre         397 non-null float64
# gpa         397 non-null float64
# prestige    397 non-null float64
# dtypes: float64(3), int64(1)
# memory usage: 15.5 KB

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
#boxplot 1
df_no_missing.boxplot('gre')
# Out:
# C:\Users\updadmin\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   from ipykernel import kernelapp as app
# {'boxes': [<matplotlib.lines.Line2D at 0xda13cf8>],
#  'caps': [<matplotlib.lines.Line2D at 0xda23be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xda33c88>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xda33710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xda23080>,
#   <matplotlib.lines.Line2D at 0xda23668>]}

# %%
#boxplot 2 
df_no_missing.boxplot('gpa')
# Out:
# C:\Users\updadmin\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   from ipykernel import kernelapp as app
# {'boxes': [<matplotlib.lines.Line2D at 0xdbb57b8>],
#  'caps': [<matplotlib.lines.Line2D at 0xdbc4518>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xdc155c0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xdc15048>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xdbb5978>,
#   <matplotlib.lines.Line2D at 0xdbb5f60>]}

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# The red line is the mean, the box frame is from the minimum point of 2.2 and max of 4. most of the
# observations lay within the box parameters.

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable 
import seaborn as sns
sns.distplot(df_no_missing.gre);

# %%
sns.distplot(df_no_missing.gpa);

# %%
import seaborn as sns
sns.distplot(df_no_missing.admit);

# %%
import seaborn as sns
sns.distplot(df_no_missing.prestige);

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer:NO

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer: i dont know ;/

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data

#gpa and gre are potentially colinear
plt.matshow(df_no_missing.corr())

# %%
print(df_no_missing.corr())
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.181202  0.174116 -0.243563
# gre       0.181202  1.000000  0.382408 -0.124533
# gpa       0.174116  0.382408  1.000000 -0.060976
# prestige -0.243563 -0.124533 -0.060976  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# prestige and admissions are negatively correlated, gra and gpe have the highest correlation coefficient

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer: we will need to get information on the applicants, which undergrad school they finished, prestge of school and their gre, gpa, gmat? and how all that helped them to get into grad school. if there is  a correlation between prestige and acceptance status.

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: the null hypothesis would be that prestige doesn't affect acceptance at grad school.

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
